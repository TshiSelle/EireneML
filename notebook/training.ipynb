# %%
import random
import json
import pickle
import numpy as np
import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
import random
# nltk.download('omw-1.4')
import warnings
warnings.filterwarnings("ignore")
# Natural language toolkit
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignore_letters = ['?', '!', '.', ',','@']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# print(documents)

word = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))
# print(words)

training = []
output_empty = [0] * len(classes)

for document in documents:
    bag = []
    word_patterns = document[0]
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
hist = model.fit(np.array(train_x), np.array(train_y), epochs=20, batch_size=5, verbose=1)
model.save('eirene.h5', hist)

print("Done")
# Out:
# C:\Users\MT\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:60: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# Epoch 1/20
# 4953/4953 [==============================] - 4s 752us/sample - loss: 0.1681 - acc: 0.9590s - loss: 0.3793 - acc:  - ETA: 2s - loss: 0.3 - ETA: 1s - loss: 0.2302 - acc: 0.9 - ETA: 1s - loss: 0.21 - ETA: 0s - loss: 0.185
# Epoch 2/20
# 4953/4953 [==============================] - 4s 801us/sample - loss: 0.0851 - acc: 0.9792s - loss: 0.0611 - acc: 0.984 - ETA: 3s -
# Epoch 3/20
# 4953/4953 [==============================] - 4s 780us/sample - loss: 0.0746 - acc: 0.9800
# Epoch 4/20
# 4953/4953 [==============================] - 4s 729us/sample - loss: 0.0650 - acc: 0.9814s - loss: 0.0672 - acc: 0 - ETA: 1s - loss: 0.0627 - acc: - ETA: 1s - loss: 0.0631 - acc: 0 - ETA: 1s - loss
# Epoch 5/20
# 4953/4953 [==============================] - 4s 757us/sample - loss: 0.0594 - acc: 0.9818:
# Epoch 6/20
# 4953/4953 [==============================] - ETA: 0s - loss: 0.0572 - acc: 0.983 - 4s 865us/sample - loss: 0.0580 - acc: 0.9830
# Epoch 7/20
# 4953/4953 [==============================] - 4s 798us/sample - loss: 0.0518 - acc: 0.9836s - los - ETA: 0s - loss: 0.0510 - acc:
# Epoch 8/20
# 4953/4953 [==============================] - 4s 833us/sample - loss: 0.0532 - acc: 0.9822s - loss: 0.0508 - acc: 0
# Epoch 9/20
# 4953/4953 [==============================] - 4s 776us/sample - loss: 0.0462 - acc: 0.9849s - loss: 0.0454 - acc:
# Epoch 10/20
# 4953/4953 [==============================] - 4s 759us/sample - loss: 0.0395 - acc: 0.9869
# Epoch 11/20
# 4953/4953 [==============================] - 4s 747us/sample - loss: 0.0389 - acc: 0.9871s - lo
# Epoch 12/20
# 4953/4953 [==============================] - 4s 813us/sample - loss: 0.0402 - acc: 0.9865
# Epoch 13/20
# 4953/4953 [==============================] - 5s 935us/sample - loss: 0.0365 - acc: 0.9869s - loss: 0. - ETA: 0s - loss: 0.0362 -
# Epoch 14/20
# 4953/4953 [==============================] - 4s 808us/sample - loss: 0.0350 - acc: 0.9891s - loss: 0.0359
# Epoch 15/20
# 4953/4953 [==============================] - 4s 815us/sample - loss: 0.0323 - acc: 0.9885s - loss: 0.0322 - acc: 0.9
# Epoch 16/20
# 4953/4953 [==============================] - 4s 769us/sample - loss: 0.0294 - acc: 0.9891s - loss: 0 - ETA: 2s - l - ETA: 0s - loss: 0.02
# Epoch 17/20
# 4953/4953 [==============================] - 4s 763us/sample - loss: 0.0329 - acc: 0.9899s - loss: 0.0251 - acc: 0.98 - ETA: 3s - loss: 0.0249 - ETA: 2s - loss: 0.0236 - acc: 0. - ET - ETA: 0s - loss: 0.0322 - acc: 0.9 - ETA: 0s - loss: 0.0328 - acc:
# Epoch 18/20
# 4953/4953 [==============================] - 4s 734us/sample - loss: 0.0265 - acc: 0.9919A: 3s - loss: 0.0273 - acc: 0.995 - ETA: 3s - loss: 0.0299 - acc: 0.993 - - ETA: 1s - loss: 0.02 - ETA: 0s - loss: 0.0259 - acc:  - ETA: 0s - loss: 0.0247 - acc:
# Epoch 19/20
# 4953/4953 [==============================] - 4s 778us/sample - loss: 0.0282 - acc: 0.9909s - loss: 0.0
# Epoch 20/20
# 4953/4953 [==============================] - 4s 826us/sample - loss: 0.0254 - acc: 0.9913
# Done
